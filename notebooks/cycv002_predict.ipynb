# %%
# !pip install uv --quiet
# !git clone  https://github.com/abdulrahman1238/clothes-segmentation-cvcy002
# %cd /content/clothes-segmentation-cvcy002
# !ls
# !uv sync
print("✅ Setup complete!")
# Out:
# /content/clothes-segmentation-cvcy002
# configs  pyproject.toml  README.md  scripts  src  uv.lock
# Using CPython 3.10.12 interpreter at: /usr/bin/python3.10
# Creating virtual environment at: .venv
# Resolved 81 packages in 1ms
# Prepared 71 packages in 1m 47s
# Installed 71 packages in 697ms
#  + albucore==0.0.24
#  + albumentations==2.0.8
#  + annotated-types==0.8.0
#  + anyio==4.14.2
#  + certifi==2026.7.22
#  + click==8.4.2
#  + contourpy==1.3.2
#  + cuda-bindings==12.9.7
#  + cuda-pathfinder==1.6.0
#  + cuda-toolkit==12.6.3
#  + cvcy002==0.1.0 (from file:///content/clothes-segmentation-cvcy002)
#  + cycler==0.12.1
#  + exceptiongroup==1.3.1
#  + filelock==3.32.3
#  + fonttools==4.63.0
#  + fsspec==2026.6.0
#  + h11==0.16.0
#  + hf-xet==1.6.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==1.28.0
#  + idna==3.19
#  + jinja2==3.1.6
#  + joblib==1.5.3
#  + kiwisolver==1.5.0
#  + markupsafe==3.0.3
#  + matplotlib==3.10.9
#  + mpmath==1.3.0
#  + networkx==3.4.2
#  + numpy==2.2.6
#  + nvidia-cublas-cu12==12.6.4.1
#  + nvidia-cuda-cupti-cu12==12.6.80
#  + nvidia-cuda-nvrtc-cu12==12.6.85
#  + nvidia-cuda-runtime-cu12==12.6.77
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.0.4
#  + nvidia-cufile-cu12==1.11.1.6
#  + nvidia-curand-cu12==10.3.7.77
#  + nvidia-cusolver-cu12==11.7.1.2
#  + nvidia-cusparse-cu12==12.5.4.2
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.29.3
#  + nvidia-nvjitlink-cu12==12.6.85
#  + nvidia-nvshmem-cu12==3.4.5
#  + nvidia-nvtx-cu12==12.6.77
#  + opencv-python==5.0.0.93
#  + opencv-python-headless==5.0.0.93
#  + packaging==26.3
#  + pillow==12.3.0
#  + pydantic==2.13.4
#  + pydantic-core==2.46.4
#  + pyparsing==3.3.2
#  + python-dateutil==2.9.0.post0
#  + pyyaml==6.0.3
#  + safetensors==0.8.0
#  + scikit-learn==1.7.2
#  + scipy==1.15.3
#  + segmentation-models-pytorch==0.5.0
#  + setuptools==78.1.0
#  + simsimd==6.5.16
#  + six==1.17.0
#  + stringzilla==5.1.2
#  + sympy==1.14.0
#  + threadpoolctl==3.6.0
#  + timm==1.0.28
#  + torch==2.13.0+cu126
#  + torchvision==0.28.0+cu126
#  + tqdm==4.70.0
#  + triton==3.7.1
#  + typing-extensions==4.16.0
#  + typing-inspection==0.4.4
# ✅ Setup complete!

# %%
from google.colab import drive
drive.mount('/content/drive')


# Copy the file to your current directory
# !cp "/content/drive/MyDrive/cvcy002/best_model.pth" /content/clothes-segmentation-cvcy002

# %%
# !MPLBACKEND=Agg uv run python scripts/predict.py \
    --checkpoint /content/clothes-segmentation-cvcy002/best_model.pth \
    --image_path /content/241_190379.jpg \
    --output_path outputs/my_prediction2.png
# Out:
# Building DeepLabV3+ | Backbone: resnet50 | Classes: 2 | Pretrained: True
#  Loaded checkpoint from epoch 13
# Blended prediction saved to: outputs/my_prediction2.png
# Comparison grid saved to: outputs/my_prediction2_grid.png
